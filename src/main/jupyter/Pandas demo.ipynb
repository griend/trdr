# %% [markdown]
# # Pandas demo

# %% [markdown]
# Load Python modules and setup the connection with the SQLite database.

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import pandas as pd
import sqlite3

db_filename = '/Users/cees/var/trader/db/trader.db'

connection = sqlite3.connect(db_filename)
connection.row_factory = sqlite3.Row
cursor = connection.cursor()

# %% [markdown]
# Create a Pandas Dataframe by querying the SQLite database.

# %%
df = pd.read_sql('SELECT * FROM markets',
                 connection,
                 index_col='id', 
                 parse_dates={'created_on': 's', 'updated_on': 's'})

df.head()
# Out:
#        market   status   base quote  pricePrecision  minOrderInQuoteAsset  \
# id
# 1   1INCH-EUR  trading  1INCH   EUR               5                 5.000
# 2    AAVE-EUR  trading   AAVE   EUR               5                 5.000
# 3     ADA-BTC   halted    ADA   BTC               5                 0.001
# 4     ADA-EUR  trading    ADA   EUR               5                 5.000
# 5     ADX-EUR  trading    ADX   EUR               5                 5.000
#
#     minOrderInBaseAsset                                         orderTypes  \
# id
# 1                 2.000  market, limit, stopLoss, stopLossLimit, takePr...
# 2                 0.008  market, limit, stopLoss, stopLossLimit, takePr...
# 3                10.000  market, limit, stopLoss, stopLossLimit, takePr...
# 4                 3.000  market, limit, stopLoss, stopLossLimit, takePr...
# 5                10.000  market, limit, stopLoss, stopLossLimit, takePr...
#
#             created_on          updated_on
# id
# ...

# %% [markdown]
# A silly example of a plot, because the dataframe only contains metadata.

# %%
df.plot()
plt.title('Test')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Test')
